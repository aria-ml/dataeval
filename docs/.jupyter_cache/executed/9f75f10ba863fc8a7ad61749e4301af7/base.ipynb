# %%
try:
    import google.colab  # noqa: F401

    # specify the version of DataEval (==X.XX.X) for versions other than the latest
    # %pip install -q dataeval[torch]
except Exception:
    pass

# %%
import numpy as np
import torch
import torchvision.datasets as datasets
import torchvision.transforms.v2 as v2

from dataeval.detectors.linters import Outliers

# %%
# Load in the cifar-10 dataset from torchvision
to_tensor = v2.Compose([v2.ToImage(), v2.ToDtype(torch.float32, scale=True)])
testing_dataset = datasets.CIFAR10("./data", train=False, download=True, transform=to_tensor)
test_data = np.array(testing_dataset.data, dtype=float)
# Out:
# Files already downloaded and verified

# %%
# Initialize the Duplicates class
outliers = Outliers()

# Evaluate the data
results = outliers.evaluate(test_data)
# Out:
# /home/aweng/dataeval/src/dataeval/_internal/detectors/outliers.py:57: RuntimeWarning: invalid value encountered in divide
#   mod_z_score = 0.6745 * abs_diff / med_abs_diff

# %%
print(f"Total number of images with an issue: {len(results.issues)}")
# Out:
# Total number of images with an issue: 1401

# %%
# Show each image that has at least one issue
for image, issue in results.issues.items():
    print(f"{image} - {issue}")
# Out:
# 7 - {'kurtosis': 2.695}
# 16 - {'zeros': 0.6147}
# 21 - {'skew': -2.49, 'kurtosis': 4.53, 'entropy': 3.182, 'darkness': 0.937, 'zeros': 1.333}
# 41 - {'kurtosis': 1.692, 'contrast': 3.293}
# 43 - {'kurtosis': 2.234}
# 55 - {'entropy': 4.227}
# 57 - {'contrast': 3.352, 'zeros': 6.688}
# 60 - {'blurriness': 95.75}
# 62 - {'zeros': 0.5312}
# 70 - {'kurtosis': 1.848}
# 72 - {'kurtosis': 2.037}
# 75 - {'blurriness': 112.4}
# 79 - {'entropy': 4.01}
# 81 - {'contrast': 3.55, 'zeros': 3.291}
# 93 - {'blurriness': 93.06}
# 97 - {'skew': -4.293, 'kurtosis': 20.39, 'entropy': 3.14}
# 98 - {'entropy': 3.068}
# 102 - {'contrast': 3.371, 'zeros': 1.448}
# 105 - {'entropy': 3.799}
# 106 - {'kurtosis': 3.941}
# 109 - {'var': 0.1293}
# 110 - {'blurriness': 91.9}
# 111 - {'zeros': 0.8438}
# 112 - {'blurriness': 103.75}
# 118 - {'kurtosis': 2.031, 'entropy': 3.957, 'contrast': 3.727, 'zeros': 5.895}
# 123 - {'blurriness': 114.44}
# 162 - {'zeros': 1.0}
# 163 - {'blurriness': 91.44}
# 167 - {'kurtosis': 3.242}
# 176 - {'blurriness': 107.44}
# 180 - {'entropy': 3.676}
# 183 - {'kurtosis': 2.148}
# 188 - {'entropy': 3.773}
# 190 - {'blurriness': 90.56}
# 195 - {'kurtosis': 2.217}
# 197 - {'darkness': 0.7725}
# 198 - {'zeros': 3.416}
# 212 - {'kurtosis': 2.105, 'darkness': 0.757}
# 215 - {'entropy': 3.602}
# 218 - {'mean': 0.932, 'kurtosis': 2.393, 'entropy': 2.914, 'darkness': 0.89}
# 231 - {'var': 0.1276}
# 236 - {'kurtosis': 5.15}
# 238 - {'kurtosis': 1.809, 'entropy': 4.246}
# 244 - {'blurriness': 111.0}
# 249 - {'skew': 2.139, 'kurtosis': 3.568, 'entropy': 4.184, 'contrast': 3.695}
# 253 - {'kurtosis': 1.927}
# 269 - {'darkness': 0.745}
# 272 - {'kurtosis': 1.661}
# 273 - {'contrast': 3.498}
# 276 - {'zeros': 1.292}
# 277 - {'blurriness': 93.1}
# 286 - {'zeros': 1.2295}
# 291 - {'kurtosis': 1.705}
# 294 - {'zeros': 0.6875}
# 304 - {'kurtosis': 4.496}
# 309 - {'entropy': 4.105}
# 312 - {'kurtosis': 3.848}
# 313 - {'skew': -3.49, 'kurtosis': 17.45, 'entropy': 4.043, 'darkness': 0.8276}
# 322 - {'contrast': 3.37, 'zeros': 0.6978}
# 342 - {'entropy': 4.168}
# 345 - {'zeros': 0.4375}
# 347 - {'blurriness': 103.3}
# 374 - {'blurriness': 110.56}
# 382 - {'skew': -2.088, 'kurtosis': 3.064, 'entropy': 3.736, 'darkness': 0.9097}
# 385 - {'mean': 0.913, 'skew': -2.322, 'kurtosis': 4.94, 'entropy': 2.33, 'darkness': 0.953}
# 387 - {'blurriness': 115.0}
# 391 - {'blurriness': 107.75}
# 392 - {'blurriness': 100.1}
# 414 - {'zeros': 0.4375}
# 417 - {'zeros': 1.864}
# 420 - {'kurtosis': 2.383, 'contrast': 3.31}
# 423 - {'kurtosis': 2.963, 'contrast': 3.363}
# 437 - {'kurtosis': 3.373}
# 447 - {'kurtosis': 2.193, 'entropy': 3.44}
# 449 - {'entropy': 4.03}
# 455 - {'blurriness': 92.5}
# 456 - {'blurriness': 104.1}
# 498 - {'kurtosis': 2.11}
# 499 - {'skew': -2.994, 'kurtosis': 8.2, 'entropy': 3.906, 'darkness': 0.82}
# 502 - {'kurtosis': 2.127}
# 508 - {'entropy': 3.564}
# 522 - {'kurtosis': 1.853}
# 524 - {'darkness': 0.7373}
# 535 - {'blurriness': 91.6}
# 537 - {'kurtosis': 2.94}
# 557 - {'zeros': 0.8228}
# 564 - {'blurriness': 96.6}
# 565 - {'zeros': 0.5835}
# 574 - {'var': 0.1296, 'entropy': 4.027}
# 603 - {'kurtosis': 1.901}
# 605 - {'zeros': 5.312}
# 611 - {'kurtosis': 2.312, 'entropy': 4.07, 'darkness': 0.784}
# 616 - {'zeros': 0.521}
# 633 - {'kurtosis': 1.682}
# 649 - {'blurriness': 94.8}
# 653 - {'blurriness': 92.0}
# 659 - {'kurtosis': 2.219}
# 671 - {'zeros': 1.167}
# 674 - {'kurtosis': 6.97}
# 688 - {'entropy': 4.23}
# 706 - {'kurtosis': 2.36}
# 726 - {'kurtosis': 2.75}
# 731 - {'skew': -2.049, 'kurtosis': 3.0, 'entropy': 3.863, 'darkness': 0.784}
# 737 - {'kurtosis': 3.178}
# 744 - {'kurtosis': 2.283}
# 751 - {'entropy': 4.156}
# 763 - {'zeros': 0.5312}
# 765 - {'blurriness': 113.0}
# 778 - {'kurtosis': 2.1, 'entropy': 4.215}
# 782 - {'blurriness': 90.56}
# 790 - {'entropy': 3.73}
# 802 - {'entropy': 3.846, 'blurriness': 106.25}
# 804 - {'kurtosis': 3.83}
# 807 - {'blurriness': 110.56}
# 813 - {'blurriness': 107.25}
# 815 - {'var': 0.1334}
# 818 - {'kurtosis': 1.938}
# 834 - {'blurriness': 107.75}
# 841 - {'kurtosis': 1.774}
# 844 - {'kurtosis': 2.12}
# 857 - {'skew': -4.297, 'kurtosis': 23.66, 'entropy': 3.166}
# 872 - {'kurtosis': 2.273, 'entropy': 3.67, 'contrast': 4.01, 'zeros': 4.887}
# 883 - {'entropy': 3.377}
# 885 - {'kurtosis': 2.164}
# 888 - {'zeros': 3.01}
# 891 - {'blurriness': 114.1}
# 893 - {'entropy': 3.762}
# 907 - {'kurtosis': 3.682, 'contrast': 3.32}
# 911 - {'zeros': 0.4792}
# 925 - {'entropy': 4.04, 'zeros': 11.01}
# 928 - {'kurtosis': 2.03}
# 935 - {'entropy': 4.19, 'darkness': 0.7793}
# 943 - {'blurriness': 109.25}
# 947 - {'zeros': 0.5728}
# 957 - {'kurtosis': 3.172}
# 973 - {'kurtosis': 1.876}
# 982 - {'kurtosis': 3.2}
# 989 - {'skew': -2.88, 'kurtosis': 8.836, 'entropy': 3.883}
# 991 - {'kurtosis': 2.537}
# 994 - {'zeros': 0.9897}
# 1001 - {'kurtosis': 3.643}
# 1007 - {'zeros': 1.2295}
# 1013 - {'var': 0.1497, 'entropy': 3.568}
# 1019 - {'blurriness': 100.9}
# 1022 - {'skew': -2.193, 'kurtosis': 4.113, 'entropy': 4.152, 'darkness': 0.7646}
# 1035 - {'kurtosis': 2.693}
# 1036 - {'kurtosis': 1.847}
# 1039 - {'blurriness': 99.44}
# 1040 - {'zeros': 0.5}
# 1042 - {'kurtosis': 2.617}
# 1046 - {'kurtosis': 2.314}
# 1051 - {'blurriness': 103.2}
# 1052 - {'kurtosis': 1.615, 'entropy': 3.773, 'zeros': 0.979}
# 1062 - {'kurtosis': 2.959, 'entropy': 4.023}
# 1078 - {'mean': 0.925, 'skew': -2.672, 'kurtosis': 5.594, 'entropy': 2.037, 'darkness': 0.992}
# 1079 - {'entropy': 4.21}
# 1080 - {'zeros': 4.05}
# 1085 - {'blurriness': 100.7}
# 1086 - {'blurriness': 92.0}
# 1108 - {'zeros': 1.573}
# 1110 - {'entropy': 3.451}
# 1112 - {'contrast': 3.352}
# 1124 - {'kurtosis': 2.682}
# 1126 - {'entropy': 3.918}
# 1150 - {'zeros': 0.6562}
# 1152 - {'kurtosis': 2.094}
# 1156 - {'kurtosis': 1.681, 'zeros': 3.916}
# 1164 - {'mean': 0.8755, 'kurtosis': 2.111, 'entropy': 3.973, 'darkness': 0.816}
# 1178 - {'blurriness': 95.6}
# 1186 - {'kurtosis': 2.768}
# 1188 - {'entropy': 4.227}
# 1189 - {'kurtosis': 1.851}
# 1211 - {'kurtosis': 1.7295}
# 1240 - {'contrast': 3.521, 'zeros': 0.5728}
# 1243 - {'skew': -1.875, 'kurtosis': 4.125}
# 1249 - {'blurriness': 96.06}
# 1256 - {'entropy': 4.152}
# 1270 - {'var': 0.1301}
# 1300 - {'entropy': 3.756}
# 1303 - {'blurriness': 119.8}
# 1306 - {'kurtosis': 2.832}
# 1307 - {'entropy': 4.215, 'blurriness': 103.7, 'zeros': 0.8853}
# 1310 - {'kurtosis': 1.653}
# 1315 - {'skew': -1.934, 'kurtosis': 3.129}
# 1319 - {'skew': -1.89, 'kurtosis': 1.841, 'entropy': 3.389, 'darkness': 0.9253}
# 1327 - {'zeros': 0.8228}
# 1351 - {'entropy': 3.49, 'darkness': 0.757}
# 1365 - {'kurtosis': 1.93, 'entropy': 3.842}
# 1367 - {'entropy': 4.2}
# 1374 - {'entropy': 3.676}
# 1383 - {'kurtosis': 2.027}
# 1388 - {'kurtosis': 2.447}
# 1416 - {'zeros': 0.5625}
# 1418 - {'blurriness': 104.5}
# 1441 - {'blurriness': 92.4}
# 1446 - {'kurtosis': 1.9375}
# 1451 - {'blurriness': 98.4}
# 1494 - {'var': 0.1628}
# 1495 - {'kurtosis': 1.632}
# 1496 - {'blurriness': 111.7, 'zeros': 0.9375}
# 1497 - {'zeros': 0.4792}
# 1498 - {'blurriness': 101.6}
# 1510 - {'blurriness': 102.2}
# 1511 - {'entropy': 3.65}
# 1522 - {'blurriness': 106.56}
# 1524 - {'kurtosis': 1.801}
# 1541 - {'blurriness': 111.9}
# 1547 - {'skew': -2.135, 'kurtosis': 3.42}
# 1561 - {'zeros': 0.7812}
# 1579 - {'blurriness': 103.3}
# 1586 - {'kurtosis': 1.711}
# 1590 - {'kurtosis': 3.018}
# 1595 - {'blurriness': 98.2}
# 1609 - {'kurtosis': 3.42}
# 1615 - {'entropy': 3.764}
# 1621 - {'kurtosis': 1.643}
# 1623 - {'kurtosis': 2.057}
# 1629 - {'skew': -1.922, 'kurtosis': 2.652, 'entropy': 3.605, 'darkness': 0.8276}
# 1632 - {'zeros': 0.7397}
# 1638 - {'kurtosis': 1.801}
# 1640 - {'zeros': 2.959}
# 1642 - {'blurriness': 98.44}
# 1645 - {'kurtosis': 1.903}
# 1646 - {'kurtosis': 2.057, 'entropy': 4.16, 'darkness': 0.8354}
# 1651 - {'entropy': 4.18, 'blurriness': 111.9}
# 1664 - {'mean': 0.919, 'skew': -3.896, 'kurtosis': 16.1, 'entropy': 3.34, 'darkness': 0.9414}
# 1670 - {'kurtosis': 2.764}
# 1671 - {'zeros': 0.4895}
# 1675 - {'skew': 2.098, 'kurtosis': 4.418}
# 1677 - {'skew': 2.078, 'kurtosis': 4.027, 'contrast': 3.365}
# 1678 - {'kurtosis': 2.025}
# 1689 - {'zeros': 0.5}
# 1694 - {'mean': 0.884, 'skew': -2.781, 'kurtosis': 7.082, 'entropy': 3.508, 'darkness': 0.933}
# 1713 - {'zeros': 0.5103}
# 1722 - {'zeros': 1.6875}
# 1729 - {'zeros': 0.5312}
# 1734 - {'zeros': 0.5728}
# 1735 - {'kurtosis': 3.006}
# 1748 - {'entropy': 3.87}
# 1758 - {'blurriness': 105.1}
# 1759 - {'kurtosis': 3.516}
# 1762 - {'blurriness': 93.2}
# 1776 - {'entropy': 3.76}
# 1787 - {'kurtosis': 1.623, 'entropy': 3.82, 'darkness': 0.757}
# 1797 - {'zeros': 0.8228}
# 1802 - {'kurtosis': 8.39, 'entropy': 3.889}
# 1803 - {'kurtosis': 1.964}
# 1846 - {'kurtosis': 2.22}
# 1847 - {'kurtosis': 1.71}
# 1852 - {'zeros': 0.427}
# 1862 - {'kurtosis': 2.346}
# 1875 - {'entropy': 4.027, 'blurriness': 92.4}
# 1876 - {'kurtosis': 1.894}
# 1878 - {'zeros': 1.0}
# 1880 - {'zeros': 1.511}
# 1892 - {'zeros': 0.5}
# 1895 - {'var': 0.1372}
# 1899 - {'blurriness': 93.56}
# 1904 - {'entropy': 4.19}
# 1913 - {'entropy': 3.787}
# 1916 - {'kurtosis': 3.07}
# 1918 - {'blurriness': 104.4, 'zeros': 0.5728}
# 1921 - {'entropy': 4.195, 'zeros': 2.896}
# 1928 - {'blurriness': 96.9}
# 1929 - {'kurtosis': 1.867}
# 1942 - {'blurriness': 106.6}
# 1959 - {'zeros': 1.833}
# 1968 - {'blurriness': 105.2, 'zeros': 1.1045}
# 1971 - {'kurtosis': 3.521}
# 1972 - {'kurtosis': 1.678}
# 1973 - {'entropy': 3.883}
# 1982 - {'kurtosis': 1.611}
# 1985 - {'blurriness': 106.1}
# 1988 - {'zeros': 0.9478}
# 1996 - {'kurtosis': 2.793}
# 1997 - {'entropy': 3.973}
# 1998 - {'kurtosis': 3.123}
# 2004 - {'var': 0.1405}
# 2010 - {'entropy': 4.203, 'zeros': 9.6}
# 2025 - {'entropy': 4.08}
# 2041 - {'kurtosis': 2.885, 'darkness': 0.741}
# 2059 - {'kurtosis': 2.07}
# 2067 - {'blurriness': 105.94}
# 2072 - {'entropy': 4.28}
# 2078 - {'kurtosis': 3.205}
# 2079 - {'entropy': 3.898}
# 2090 - {'skew': -3.041, 'kurtosis': 8.945, 'entropy': 3.584}
# 2091 - {'skew': 2.348, 'kurtosis': 5.652}
# 2095 - {'kurtosis': 1.621}
# 2097 - {'kurtosis': 2.078}
# 2103 - {'blurriness': 102.06}
# 2110 - {'kurtosis': 1.63}
# 2113 - {'kurtosis': 1.745}
# 2119 - {'zeros': 0.8228}
# 2121 - {'kurtosis': 6.72, 'entropy': 4.246}
# 2122 - {'skew': -1.964, 'kurtosis': 3.143, 'darkness': 0.753}
# 2126 - {'entropy': 3.615}
# 2128 - {'blurriness': 101.44}
# 2130 - {'entropy': 4.258}
# 2137 - {'kurtosis': 2.076}
# 2139 - {'zeros': 0.7812}
# 2166 - {'blurriness': 115.06}
# 2169 - {'kurtosis': 5.3}
# 2175 - {'kurtosis': 1.839}
# 2179 - {'entropy': 3.322}
# 2191 - {'kurtosis': 2.219}
# 2199 - {'blurriness': 119.4}
# 2200 - {'entropy': 3.918, 'blurriness': 99.7}
# 2201 - {'zeros': 0.6147}
# 2210 - {'skew': -2.633, 'kurtosis': 7.086, 'entropy': 4.25, 'darkness': 0.749}
# 2214 - {'blurriness': 120.2}
# 2215 - {'entropy': 4.156}
# 2221 - {'blurriness': 114.3}
# 2235 - {'kurtosis': 2.082}
# 2247 - {'blurriness': 109.25}
# 2251 - {'darkness': 0.745}
# 2258 - {'blurriness': 94.4}
# 2266 - {'zeros': 1.886}
# 2288 - {'blurriness': 110.8}
# 2309 - {'kurtosis': 1.914}
# 2312 - {'kurtosis': 1.698}
# 2313 - {'blurriness': 117.6}
# 2314 - {'darkness': 0.8037}
# 2315 - {'kurtosis': 1.676}
# 2318 - {'blurriness': 96.8}
# 2325 - {'blurriness': 95.7}
# 2332 - {'entropy': 4.234, 'darkness': 0.7295}
# 2339 - {'kurtosis': 1.841}
# 2345 - {'blurriness': 104.94, 'zeros': 0.771}
# 2353 - {'blurriness': 96.25}
# 2362 - {'kurtosis': 1.91}
# 2373 - {'skew': -2.164, 'kurtosis': 3.588, 'entropy': 3.951, 'darkness': 0.9097}
# 2381 - {'zeros': 4.895}
# 2383 - {'kurtosis': 2.404}
# 2390 - {'kurtosis': 2.355, 'zeros': 1.261}
# 2391 - {'kurtosis': 3.037}
# 2394 - {'blurriness': 120.2}
# 2400 - {'mean': 0.898, 'skew': -2.146, 'kurtosis': 3.096, 'entropy': 2.582, 'darkness': 0.9727}
# 2403 - {'kurtosis': 1.831}
# 2405 - {'zeros': 0.4375}
# 2411 - {'kurtosis': 4.37}
# 2426 - {'entropy': 3.215}
# 2430 - {'kurtosis': 2.266}
# 2435 - {'blurriness': 119.6}
# 2439 - {'blurriness': 96.06}
# 2443 - {'kurtosis': 2.092, 'darkness': 0.757}
# 2448 - {'blurriness': 97.6}
# 2455 - {'kurtosis': 3.54, 'contrast': 3.303}
# 2456 - {'skew': -2.186, 'kurtosis': 3.986, 'entropy': 4.098, 'darkness': 0.858}
# 2461 - {'entropy': 4.008}
# 2463 - {'entropy': 4.25}
# 2468 - {'entropy': 3.885}
# 2484 - {'zeros': 0.8125}
# 2486 - {'blurriness': 98.1}
# 2494 - {'darkness': 0.791}
# 2499 - {'blurriness': 90.7, 'zeros': 0.4375}
# 2501 - {'kurtosis': 2.186}
# 2507 - {'kurtosis': 13.695, 'entropy': 3.572}
# 2509 - {'kurtosis': 1.856}
# 2519 - {'kurtosis': 2.658}
# 2533 - {'kurtosis': 1.681, 'entropy': 3.902}
# 2537 - {'zeros': 0.4583}
# 2538 - {'kurtosis': 1.608}
# 2542 - {'kurtosis': 1.842}
# 2558 - {'kurtosis': 1.694}
# 2563 - {'entropy': 4.004}
# 2570 - {'kurtosis': 4.695}
# 2582 - {'blurriness': 92.75}
# 2585 - {'kurtosis': 3.896}
# 2589 - {'entropy': 4.273}
# 2595 - {'blurriness': 97.25}
# 2608 - {'blurriness': 116.6}
# 2617 - {'var': 0.1327, 'zeros': 3.01}
# 2622 - {'kurtosis': 3.104, 'entropy': 4.266}
# 2630 - {'kurtosis': 2.344}
# 2641 - {'blurriness': 103.1}
# 2662 - {'kurtosis': 1.943}
# 2663 - {'zeros': 0.8853}
# 2668 - {'skew': -2.24, 'kurtosis': 10.555, 'entropy': 4.094}
# 2669 - {'kurtosis': 2.215}
# 2672 - {'entropy': 3.596}
# 2691 - {'blurriness': 105.7}
# 2699 - {'blurriness': 103.44}
# 2702 - {'kurtosis': 1.917}
# 2705 - {'kurtosis': 2.283}
# 2707 - {'kurtosis': 2.35}
# 2708 - {'zeros': 0.4375}
# 2714 - {'entropy': 4.24}
# 2717 - {'kurtosis': 1.904}
# 2724 - {'kurtosis': 2.807}
# 2729 - {'entropy': 2.775, 'darkness': 0.894}
# 2734 - {'zeros': 0.4583}
# 2740 - {'zeros': 1.5}
# 2746 - {'entropy': 4.277, 'contrast': 3.572, 'zeros': 8.055}
# 2747 - {'zeros': 3.75}
# 2751 - {'blurriness': 92.9}
# 2752 - {'zeros': 3.76}
# 2754 - {'skew': 2.143, 'kurtosis': 3.758, 'entropy': 2.912, 'contrast': 4.523, 'zeros': 2.928}
# 2756 - {'blurriness': 110.44}
# 2757 - {'var': 0.1317, 'zeros': 0.7397}
# 2760 - {'kurtosis': 1.813}
# 2763 - {'blurriness': 115.44}
# 2766 - {'blurriness': 115.1}
# 2767 - {'entropy': 4.23}
# 2772 - {'blurriness': 120.2, 'zeros': 0.9478}
# 2792 - {'entropy': 4.227, 'darkness': 0.749}
# 2794 - {'entropy': 3.832}
# 2797 - {'blurriness': 111.4}
# 2807 - {'zeros': 0.854}
# 2810 - {'var': 0.1307}
# 2812 - {'skew': -2.154, 'kurtosis': 4.477, 'entropy': 4.22}
# 2824 - {'blurriness': 105.3}
# 2825 - {'kurtosis': 1.691}
# 2826 - {'kurtosis': 2.139}
# 2834 - {'blurriness': 106.56}
# 2836 - {'entropy': 3.91}
# 2838 - {'kurtosis': 1.93}
# 2839 - {'blurriness': 101.2}
# 2840 - {'entropy': 3.107, 'zeros': 15.43}
# 2841 - {'blurriness': 93.3}
# 2859 - {'kurtosis': 3.045}
# 2871 - {'entropy': 3.584, 'darkness': 0.745}
# 2877 - {'zeros': 1.406}
# 2896 - {'zeros': 0.8022}
# 2903 - {'entropy': 4.23}
# 2918 - {'kurtosis': 4.027}
# 2927 - {'blurriness': 102.8}
# 2938 - {'skew': -2.121, 'kurtosis': 4.35, 'entropy': 4.223}
# 2940 - {'entropy': 3.771, 'contrast': 3.828, 'zeros': 3.791}
# 2955 - {'kurtosis': 2.707}
# 2956 - {'skew': -2.334, 'kurtosis': 5.496, 'entropy': 4.023}
# 2963 - {'zeros': 0.5835}
# 2964 - {'blurriness': 104.0}
# 2967 - {'zeros': 1.906}
# 2968 - {'entropy': 4.28, 'blurriness': 118.56}
# 2978 - {'zeros': 0.979}
# 2979 - {'entropy': 4.117}
# 2995 - {'skew': 2.904, 'kurtosis': 10.59, 'entropy': 4.164}
# 2999 - {'blurriness': 104.8}
# 3034 - {'entropy': 4.227}
# 3038 - {'kurtosis': 3.01}
# 3039 - {'blurriness': 100.5}
# 3056 - {'blurriness': 92.0}
# 3059 - {'var': 0.1378}
# 3066 - {'var': 0.1305}
# 3068 - {'entropy': 3.592}
# 3070 - {'kurtosis': 2.664}
# 3094 - {'entropy': 3.633}
# 3098 - {'blurriness': 114.5}
# 3101 - {'zeros': 0.9165}
# 3103 - {'blurriness': 110.2}
# 3108 - {'entropy': 4.18}
# 3117 - {'entropy': 3.506}
# 3119 - {'skew': 2.105, 'kurtosis': 4.902, 'entropy': 4.008, 'contrast': 4.023, 'zeros': 1.2705}
# 3125 - {'zeros': 2.385}
# 3127 - {'kurtosis': 2.244}
# 3147 - {'kurtosis': 2.72, 'entropy': 4.19}
# 3164 - {'kurtosis': 1.699}
# 3165 - {'kurtosis': 1.615, 'blurriness': 92.1}
# 3169 - {'zeros': 0.7603}
# 3170 - {'zeros': 0.5312}
# 3171 - {'zeros': 2.104}
# 3177 - {'entropy': 4.2}
# 3178 - {'blurriness': 94.3}
# 3183 - {'kurtosis': 1.762}
# 3190 - {'entropy': 4.137}
# 3197 - {'blurriness': 105.2}
# 3201 - {'zeros': 1.0}
# 3206 - {'skew': -2.002, 'kurtosis': 4.566, 'entropy': 3.275, 'darkness': 0.7715}
# 3209 - {'blurriness': 105.3}
# 3221 - {'blurriness': 112.8}
# 3226 - {'skew': -2.451, 'kurtosis': 6.418}
# 3227 - {'blurriness': 119.8}
# 3248 - {'entropy': 3.57}
# 3252 - {'blurriness': 110.44}
# 3254 - {'var': 0.1398}
# 3263 - {'blurriness': 93.5}
# 3278 - {'entropy': 3.762}
# 3281 - {'kurtosis': 2.742}
# 3294 - {'skew': -1.995, 'kurtosis': 3.084, 'darkness': 0.792}
# 3304 - {'blurriness': 93.2}
# 3310 - {'blurriness': 99.2}
# 3312 - {'kurtosis': 3.55}
# 3326 - {'blurriness': 96.2}
# 3343 - {'var': 0.1377, 'zeros': 0.8125}
# 3348 - {'entropy': 4.14}
# 3354 - {'entropy': 4.06}
# 3356 - {'skew': 2.879, 'kurtosis': 10.78, 'contrast': 3.383}
# 3357 - {'kurtosis': 1.93}
# 3360 - {'kurtosis': 3.256}
# 3361 - {'zeros': 1.1875}
# 3370 - {'zeros': 0.5}
# 3378 - {'blurriness': 117.1}
# 3379 - {'blurriness': 101.56}
# 3393 - {'kurtosis': 3.168}
# 3400 - {'entropy': 4.02, 'contrast': 3.705}
# 3401 - {'blurriness': 105.25}
# 3403 - {'kurtosis': 3.133}
# 3408 - {'blurriness': 114.6}
# 3422 - {'zeros': 0.448}
# 3426 - {'darkness': 0.753}
# 3429 - {'entropy': 3.91}
# 3439 - {'kurtosis': 2.008}
# 3442 - {'var': 0.1349, 'entropy': 4.242}
# 3443 - {'blurriness': 98.9}
# 3444 - {'mean': 0.9883, 'skew': -8.555, 'kurtosis': 77.6, 'entropy': 1.039, 'darkness': 1.0}
# 3471 - {'var': 0.1556}
# 3472 - {'zeros': 0.4688}
# 3475 - {'skew': -3.092, 'kurtosis': 11.01, 'entropy': 3.867}
# 3480 - {'blurriness': 109.2}
# 3483 - {'kurtosis': 1.893}
# 3484 - {'kurtosis': 2.693}
# 3485 - {'var': 0.1292, 'zeros': 1.333}
# 3498 - {'zeros': 1.239}
# 3512 - {'blurriness': 104.06}
# 3522 - {'blurriness': 100.94}
# 3536 - {'skew': -2.115, 'kurtosis': 4.27, 'entropy': 4.07, 'darkness': 0.8237}
# 3537 - {'kurtosis': 5.41}
# 3541 - {'blurriness': 95.6}
# 3550 - {'kurtosis': 1.729}
# 3551 - {'mean': 0.9175, 'skew': -2.438, 'kurtosis': 6.47, 'entropy': 3.012, 'darkness': 0.894}
# 3561 - {'zeros': 0.7812}
# 3563 - {'kurtosis': 1.996}
# 3566 - {'kurtosis': 1.947}
# 3573 - {'kurtosis': 1.896}
# 3574 - {'kurtosis': 4.547}
# 3576 - {'blurriness': 105.44}
# 3582 - {'kurtosis': 2.354, 'entropy': 3.06, 'contrast': 4.45, 'zeros': 15.32}
# 3588 - {'kurtosis': 2.307}
# 3591 - {'blurriness': 98.94}
# 3597 - {'kurtosis': 2.205}
# 3598 - {'entropy': 4.0}
# 3621 - {'skew': -2.188, 'kurtosis': 3.71, 'entropy': 3.664, 'darkness': 0.9136}
# 3624 - {'blurriness': 103.8}
# 3629 - {'var': 0.1406, 'zeros': 0.604}
# 3633 - {'zeros': 0.6772}
# 3634 - {'var': 0.1282}
# 3648 - {'kurtosis': 5.395}
# 3650 - {'blurriness': 120.0}
# 3673 - {'kurtosis': 3.584}
# 3681 - {'blurriness': 109.9}
# 3688 - {'var': 0.1628}
# 3704 - {'kurtosis': 1.703}
# 3713 - {'contrast': 3.37, 'zeros': 1.8125}
# 3720 - {'kurtosis': 4.273}
# 3721 - {'blurriness': 90.6}
# 3724 - {'skew': 2.605, 'kurtosis': 7.594, 'contrast': 3.652}
# 3725 - {'blurriness': 101.1}
# 3757 - {'skew': -2.143, 'kurtosis': 4.82}
# 3758 - {'skew': 2.377, 'kurtosis': 5.734, 'contrast': 4.086, 'zeros': 1.989}
# 3759 - {'blurriness': 99.4}
# 3764 - {'entropy': 2.8, 'darkness': 0.7686}
# 3767 - {'kurtosis': 3.791}
# 3770 - {'zeros': 0.5312}
# 3782 - {'entropy': 3.598}
# 3789 - {'blurriness': 93.0}
# 3794 - {'entropy': 3.793}
# 3797 - {'blurriness': 100.44}
# 3802 - {'zeros': 0.4583}
# 3808 - {'kurtosis': 2.021}
# 3810 - {'blurriness': 103.44}
# 3816 - {'blurriness': 99.6}
# 3823 - {'mean': 0.911, 'skew': -2.332, 'kurtosis': 4.33, 'entropy': 2.754, 'darkness': 0.9727}
# 3828 - {'entropy': 3.877}
# 3845 - {'entropy': 3.465}
# 3851 - {'blurriness': 109.44}
# 3863 - {'blurriness': 105.8}
# 3870 - {'kurtosis': 2.201}
# 3917 - {'blurriness': 91.0}
# 3953 - {'blurriness': 91.25}
# 3963 - {'zeros': 0.4688}
# 3967 - {'kurtosis': 1.705}
# 3976 - {'zeros': 0.448}
# 3977 - {'blurriness': 97.5}
# 3986 - {'zeros': 3.447}
# 3990 - {'blurriness': 110.9}
# 4008 - {'kurtosis': 1.856}
# 4009 - {'zeros': 1.1455}
# 4013 - {'zeros': 1.8545}
# 4015 - {'zeros': 0.5312}
# 4032 - {'zeros': 0.9688}
# 4035 - {'zeros': 1.625}
# 4049 - {'blurriness': 112.44}
# 4052 - {'zeros': 0.8228}
# 4059 - {'zeros': 1.125}
# 4060 - {'blurriness': 114.3}
# 4072 - {'var': 0.1462}
# 4076 - {'zeros': 0.5103}
# 4077 - {'blurriness': 93.56}
# 4096 - {'skew': 2.123, 'kurtosis': 8.36, 'entropy': 4.234}
# 4102 - {'kurtosis': 5.707, 'entropy': 3.76}
# 4108 - {'kurtosis': 4.96}
# 4111 - {'kurtosis': 2.02}
# 4123 - {'blurriness': 101.5}
# 4128 - {'entropy': 3.877}
# 4132 - {'blurriness': 98.44}
# 4133 - {'kurtosis': 3.635}
# 4136 - {'entropy': 4.24}
# 4147 - {'blurriness': 91.25}
# 4157 - {'entropy': 4.28}
# 4159 - {'blurriness': 110.8}
# 4171 - {'kurtosis': 2.963}
# 4181 - {'entropy': 3.283}
# 4193 - {'entropy': 3.754, 'darkness': 0.788}
# 4204 - {'blurriness': 120.2}
# 4216 - {'skew': -2.55, 'kurtosis': 6.305, 'entropy': 3.93}
# 4220 - {'kurtosis': 1.822}
# 4234 - {'blurriness': 96.75}
# 4235 - {'blurriness': 91.1}
# 4272 - {'blurriness': 109.25}
# 4273 - {'kurtosis': 2.008, 'entropy': 4.277, 'darkness': 0.8076}
# 4279 - {'entropy': 4.06}
# 4285 - {'blurriness': 100.1}
# 4286 - {'entropy': 3.98}
# 4291 - {'entropy': 3.621}
# 4294 - {'skew': -2.021, 'kurtosis': 7.047, 'entropy': 4.188}
# 4307 - {'entropy': 4.13}
# 4309 - {'blurriness': 108.4}
# 4314 - {'kurtosis': 1.96}
# 4315 - {'kurtosis': 1.922}
# 4325 - {'blurriness': 90.94}
# 4335 - {'kurtosis': 1.715}
# 4336 - {'var': 0.1423, 'zeros': 0.625}
# 4353 - {'blurriness': 119.9}
# 4355 - {'entropy': 3.809, 'contrast': 3.727, 'zeros': 9.65}
# 4359 - {'kurtosis': 1.936}
# 4362 - {'blurriness': 94.5}
# 4364 - {'zeros': 0.7397}
# 4366 - {'kurtosis': 4.266}
# 4373 - {'blurriness': 96.8}
# 4375 - {'skew': -1.981, 'kurtosis': 5.223}
# 4379 - {'zeros': 0.6562}
# 4384 - {'kurtosis': 1.7705}
# 4388 - {'entropy': 2.904, 'darkness': 0.937}
# 4394 - {'zeros': 1.511}
# 4396 - {'zeros': 0.6772}
# 4415 - {'darkness': 0.7363}
# 4419 - {'kurtosis': 2.857}
# 4421 - {'var': 0.1371, 'entropy': 4.02, 'zeros': 4.426}
# 4423 - {'zeros': 2.322}
# 4425 - {'zeros': 0.604}
# 4426 - {'skew': -2.195, 'kurtosis': 4.5, 'entropy': 3.805, 'darkness': 0.7803}
# 4427 - {'kurtosis': 2.232, 'contrast': 3.46}
# 4429 - {'blurriness': 105.06}
# 4434 - {'mean': 0.884, 'skew': -2.342, 'kurtosis': 4.355, 'entropy': 2.807, 'darkness': 0.957}
# 4442 - {'blurriness': 107.75}
# 4446 - {'blurriness': 107.7}
# 4448 - {'blurriness': 96.94}
# 4452 - {'zeros': 0.7188}
# 4453 - {'var': 0.1643, 'blurriness': 105.44, 'zeros': 0.729}
# 4475 - {'kurtosis': 2.19, 'entropy': 3.482, 'darkness': 0.7686}
# 4478 - {'entropy': 4.188, 'contrast': 3.63}
# 4482 - {'blurriness': 93.7, 'zeros': 1.094}
# 4483 - {'entropy': 3.941}
# 4484 - {'blurriness': 117.44}
# 4488 - {'kurtosis': 1.927}
# 4504 - {'skew': -3.037, 'kurtosis': 8.805, 'entropy': 3.77, 'darkness': 0.7764}
# 4505 - {'blurriness': 119.1}
# 4512 - {'kurtosis': 3.742, 'entropy': 4.234}
# 4513 - {'zeros': 1.114}
# 4530 - {'kurtosis': 3.451, 'darkness': 0.7295}
# 4534 - {'blurriness': 111.9}
# 4535 - {'kurtosis': 2.27}
# 4545 - {'kurtosis': 2.756}
# 4546 - {'mean': 0.9194, 'skew': -4.76, 'kurtosis': 24.56, 'entropy': 3.637, 'darkness': 0.9136}
# 4550 - {'skew': 3.174, 'kurtosis': 12.586, 'entropy': 2.756, 'contrast': 4.125}
# 4552 - {'zeros': 0.6353}
# 4558 - {'skew': -2.348, 'kurtosis': 6.098, 'darkness': 0.7803}
# 4564 - {'blurriness': 101.5}
# 4566 - {'mean': 0.878, 'skew': -2.06, 'kurtosis': 3.867, 'entropy': 3.955, 'darkness': 0.847}
# 4567 - {'blurriness': 103.75}
# 4575 - {'kurtosis': 1.608}
# 4580 - {'blurriness': 120.2}
# 4587 - {'kurtosis': 1.878}
# 4590 - {'kurtosis': 2.66}
# 4634 - {'var': 0.1342, 'entropy': 4.105, 'zeros': 9.69}
# 4641 - {'blurriness': 99.25}
# 4668 - {'zeros': 2.229}
# 4669 - {'blurriness': 99.06}
# 4670 - {'kurtosis': 1.973, 'contrast': 3.328}
# 4672 - {'blurriness': 104.06}
# 4683 - {'blurriness': 100.5}
# 4691 - {'kurtosis': 5.633}
# 4694 - {'entropy': 3.809}
# 4702 - {'contrast': 3.307, 'zeros': 0.9165}
# 4711 - {'zeros': 0.4375}
# 4712 - {'kurtosis': 1.864}
# 4731 - {'kurtosis': 2.914}
# 4732 - {'kurtosis': 1.707}
# 4753 - {'std': 0.4177, 'var': 0.1746, 'entropy': 3.633, 'zeros': 3.834}
# 4756 - {'blurriness': 101.25}
# 4767 - {'entropy': 3.203}
# 4774 - {'blurriness': 113.6}
# 4781 - {'var': 0.136}
# 4790 - {'zeros': 1.167}
# 4802 - {'zeros': 0.771}
# 4811 - {'kurtosis': 1.784}
# 4814 - {'skew': 2.176, 'kurtosis': 6.0}
# 4833 - {'kurtosis': 5.168}
# 4839 - {'blurriness': 92.94}
# 4847 - {'blurriness': 92.0}
# 4858 - {'blurriness': 120.2}
# 4860 - {'kurtosis': 1.667, 'entropy': 3.848}
# 4862 - {'kurtosis': 2.06}
# 4876 - {'darkness': 0.748}
# 4883 - {'kurtosis': 2.34}
# 4891 - {'zeros': 0.4792}
# 4894 - {'blurriness': 119.1}
# 4899 - {'kurtosis': 3.947}
# 4902 - {'blurriness': 100.94}
# 4904 - {'zeros': 0.5415}
# 4909 - {'entropy': 4.035}
# 4941 - {'contrast': 3.35}
# 4944 - {'kurtosis': 1.603}
# 4957 - {'kurtosis': 2.645, 'entropy': 4.273}
# 4968 - {'mean': 0.8945, 'skew': -2.453, 'kurtosis': 5.973, 'entropy': 3.736, 'darkness': 0.898}
# 4985 - {'blurriness': 108.2}
# 4989 - {'kurtosis': 2.791, 'contrast': 3.31}
# 4991 - {'kurtosis': 1.817, 'entropy': 4.086}
# 5008 - {'blurriness': 110.7}
# 5022 - {'blurriness': 119.3}
# 5023 - {'zeros': 1.833}
# 5026 - {'blurriness': 116.06}
# 5043 - {'entropy': 4.25}
# 5044 - {'blurriness': 100.56}
# 5046 - {'kurtosis': 1.825}
# 5071 - {'zeros': 0.6978}
# 5075 - {'kurtosis': 1.7}
# 5077 - {'entropy': 4.125}
# 5084 - {'zeros': 4.76}
# 5085 - {'kurtosis': 1.928}
# 5088 - {'zeros': 0.6978}
# 5090 - {'zeros': 0.7085}
# 5097 - {'entropy': 3.646}
# 5102 - {'blurriness': 100.8}
# 5113 - {'kurtosis': 2.904}
# 5118 - {'kurtosis': 1.909}
# 5128 - {'kurtosis': 1.79}
# 5139 - {'zeros': 1.1455}
# 5148 - {'zeros': 0.9585}
# 5171 - {'zeros': 1.761}
# 5172 - {'blurriness': 98.06}
# 5174 - {'kurtosis': 2.22}
# 5186 - {'kurtosis': 1.811}
# 5189 - {'entropy': 3.875}
# 5195 - {'blurriness': 95.0}
# 5196 - {'entropy': 4.06}
# 5215 - {'zeros': 0.5938}
# 5219 - {'blurriness': 117.75}
# 5220 - {'kurtosis': 3.14, 'entropy': 4.18}
# 5224 - {'entropy': 2.885}
# 5244 - {'blurriness': 93.0}
# 5245 - {'entropy': 3.504}
# 5255 - {'kurtosis': 2.062}
# 5258 - {'zeros': 1.719}
# 5263 - {'var': 0.1665, 'entropy': 4.19, 'zeros': 0.729}
# 5264 - {'blurriness': 92.44}
# 5265 - {'kurtosis': 2.205}
# 5270 - {'contrast': 3.355, 'zeros': 4.312}
# 5274 - {'blurriness': 93.9}
# 5284 - {'zeros': 7.5}
# 5287 - {'kurtosis': 1.605}
# 5289 - {'blurriness': 113.3}
# 5302 - {'kurtosis': 4.55}
# 5310 - {'kurtosis': 4.36}
# 5330 - {'kurtosis': 2.953}
# 5331 - {'blurriness': 119.0}
# 5362 - {'blurriness': 92.75}
# 5370 - {'entropy': 3.361}
# 5374 - {'kurtosis': 2.12}
# 5379 - {'skew': 2.13, 'kurtosis': 4.16}
# 5385 - {'contrast': 3.389}
# 5391 - {'zeros': 0.5103}
# 5396 - {'var': 0.1411}
# 5402 - {'blurriness': 104.3}
# 5403 - {'blurriness': 107.9}
# 5404 - {'blurriness': 111.0}
# 5423 - {'blurriness': 117.56}
# 5431 - {'var': 0.1305}
# 5437 - {'skew': -2.463, 'kurtosis': 4.668, 'entropy': 2.168}
# 5442 - {'blurriness': 103.2}
# 5446 - {'var': 0.1399, 'entropy': 3.934}
# 5449 - {'entropy': 4.184}
# 5456 - {'contrast': 3.334, 'zeros': 3.812}
# 5460 - {'entropy': 3.695, 'zeros': 10.625}
# 5465 - {'blurriness': 91.56}
# 5469 - {'kurtosis': 4.387}
# 5473 - {'zeros': 0.6562}
# 5475 - {'entropy': 4.03}
# 5478 - {'zeros': 2.76}
# 5479 - {'kurtosis': 4.188}
# 5493 - {'skew': 2.135, 'kurtosis': 4.617}
# 5495 - {'zeros': 1.0205}
# 5496 - {'blurriness': 98.75}
# 5520 - {'zeros': 0.9478}
# 5526 - {'zeros': 0.4895}
# 5537 - {'kurtosis': 1.9375, 'entropy': 3.484, 'darkness': 0.8237}
# 5539 - {'kurtosis': 2.648, 'contrast': 3.432}
# 5545 - {'entropy': 3.932}
# 5551 - {'zeros': 0.5312}
# 5563 - {'contrast': 3.316}
# 5570 - {'var': 0.131, 'entropy': 3.95, 'zeros': 10.96}
# 5583 - {'skew': -2.559, 'kurtosis': 6.008, 'entropy': 3.863, 'darkness': 0.902}
# 5584 - {'mean': 0.8975, 'skew': -2.047, 'kurtosis': 3.232, 'entropy': 2.764, 'darkness': 0.9175}
# 5589 - {'entropy': 4.258}
# 5591 - {'zeros': 3.229}
# 5595 - {'blurriness': 116.3}
# 5599 - {'entropy': 4.07}
# 5611 - {'entropy': 3.63}
# 5613 - {'blurriness': 92.06}
# 5615 - {'kurtosis': 1.604}
# 5620 - {'blurriness': 120.2}
# 5642 - {'blurriness': 99.7}
# 5649 - {'entropy': 3.574}
# 5653 - {'zeros': 0.6665}
# 5663 - {'kurtosis': 1.732}
# 5665 - {'kurtosis': 3.863, 'entropy': 3.809}
# 5671 - {'kurtosis': 2.508, 'contrast': 3.799}
# 5704 - {'blurriness': 91.3}
# 5712 - {'blurriness': 92.5}
# 5715 - {'kurtosis': 1.635}
# 5716 - {'skew': -3.031, 'kurtosis': 10.15, 'entropy': 4.004}
# 5723 - {'kurtosis': 2.275, 'blurriness': 95.3}
# 5727 - {'blurriness': 112.25, 'zeros': 2.834}
# 5728 - {'blurriness': 94.7}
# 5729 - {'entropy': 3.912}
# 5735 - {'entropy': 4.047}
# 5740 - {'blurriness': 120.2}
# 5743 - {'zeros': 3.666}
# 5745 - {'entropy': 4.09}
# 5747 - {'kurtosis': 1.992, 'entropy': 4.258}
# 5773 - {'kurtosis': 3.254}
# 5774 - {'blurriness': 104.8}
# 5777 - {'zeros': 0.4688}
# 5785 - {'kurtosis': 3.14}
# 5788 - {'kurtosis': 2.016}
# 5792 - {'blurriness': 105.9}
# 5795 - {'blurriness': 96.3}
# 5799 - {'blurriness': 91.56}
# 5811 - {'entropy': 3.738}
# 5814 - {'zeros': 1.761}
# 5815 - {'zeros': 0.7915}
# 5829 - {'blurriness': 112.0}
# 5838 - {'contrast': 3.582, 'zeros': 2.666}
# 5839 - {'kurtosis': 2.695}
# 5842 - {'entropy': 4.105, 'contrast': 3.465, 'zeros': 4.22}
# 5845 - {'blurriness': 102.7}
# 5854 - {'kurtosis': 1.758}
# 5856 - {'blurriness': 91.4}
# 5871 - {'blurriness': 109.6}
# 5873 - {'kurtosis': 2.002}
# 5876 - {'kurtosis': 1.626}
# 5877 - {'kurtosis': 1.668}
# 5879 - {'entropy': 3.826}
# 5884 - {'kurtosis': 3.639}
# 5897 - {'blurriness': 98.2}
# 5908 - {'zeros': 1.427}
# 5912 - {'kurtosis': 2.21}
# 5913 - {'kurtosis': 1.784}
# 5922 - {'blurriness': 95.25}
# 5927 - {'kurtosis': 3.104, 'entropy': 4.227, 'contrast': 3.643, 'zeros': 1.917}
# 5944 - {'kurtosis': 2.355}
# 5953 - {'zeros': 1.4375}
# 5995 - {'entropy': 4.176}
# 6002 - {'entropy': 4.207}
# 6003 - {'mean': 0.8965, 'entropy': 2.709, 'darkness': 0.949}
# 6015 - {'zeros': 0.5835}
# 6016 - {'kurtosis': 1.717}
# 6017 - {'kurtosis': 2.768}
# 6022 - {'entropy': 3.746}
# 6023 - {'kurtosis': 2.225}
# 6026 - {'zeros': 3.479}
# 6029 - {'entropy': 3.912}
# 6035 - {'blurriness': 109.0}
# 6040 - {'zeros': 1.0205}
# 6046 - {'blurriness': 102.8}
# 6051 - {'kurtosis': 2.88}
# 6056 - {'blurriness': 91.6}
# 6065 - {'blurriness': 103.25}
# 6067 - {'kurtosis': 3.572}
# 6071 - {'kurtosis': 1.728, 'entropy': 4.254}
# 6081 - {'blurriness': 101.3}
# 6083 - {'kurtosis': 2.062}
# 6105 - {'skew': -2.064, 'kurtosis': 3.527, 'entropy': 3.652}
# 6111 - {'entropy': 3.012}
# 6112 - {'entropy': 3.8, 'contrast': 3.338, 'zeros': 11.85}
# 6123 - {'entropy': 3.574}
# 6125 - {'blurriness': 91.75}
# 6127 - {'blurriness': 107.5}
# 6128 - {'entropy': 4.277}
# 6133 - {'entropy': 4.133, 'darkness': 0.7324}
# 6138 - {'darkness': 0.7295}
# 6145 - {'contrast': 3.334}
# 6154 - {'skew': -1.885, 'kurtosis': 3.412, 'entropy': 3.953}
# 6165 - {'contrast': 3.287}
# 6170 - {'blurriness': 113.75}
# 6189 - {'entropy': 3.527}
# 6209 - {'zeros': 0.4895}
# 6232 - {'contrast': 3.42, 'zeros': 0.7812}
# 6234 - {'kurtosis': 2.91, 'entropy': 2.568, 'brightness': 0.04315, 'contrast': 4.758, 'zeros': 1.583}
# 6237 - {'blurriness': 111.9}
# 6239 - {'kurtosis': 5.13}
# 6252 - {'kurtosis': 1.84}
# 6257 - {'skew': -2.059, 'kurtosis': 3.064, 'entropy': 4.285, 'darkness': 0.7373}
# 6258 - {'kurtosis': 1.8955}
# 6263 - {'kurtosis': 2.266}
# 6265 - {'blurriness': 97.1}
# 6277 - {'kurtosis': 2.527}
# 6281 - {'zeros': 0.9272}
# 6294 - {'entropy': 3.81}
# 6299 - {'kurtosis': 1.926}
# 6305 - {'blurriness': 102.56}
# 6315 - {'var': 0.1445, 'zeros': 3.25}
# 6331 - {'entropy': 3.754}
# 6338 - {'kurtosis': 2.205}
# 6350 - {'entropy': 4.23}
# 6351 - {'entropy': 3.285}
# 6361 - {'darkness': 0.8354}
# 6365 - {'kurtosis': 2.22}
# 6372 - {'zeros': 3.635}
# 6383 - {'kurtosis': 2.49}
# 6395 - {'kurtosis': 3.09, 'darkness': 0.7607}
# 6398 - {'kurtosis': 4.273}
# 6407 - {'blurriness': 101.6}
# 6418 - {'kurtosis': 1.973}
# 6437 - {'skew': -1.854, 'kurtosis': 2.584, 'darkness': 0.8433}
# 6450 - {'mean': 0.897, 'kurtosis': 2.934, 'entropy': 3.678, 'darkness': 0.8345}
# 6455 - {'entropy': 4.2, 'zeros': 7.605}
# 6458 - {'blurriness': 105.5}
# 6475 - {'contrast': 3.455}
# 6481 - {'skew': -2.184, 'kurtosis': 3.99}
# 6494 - {'blurriness': 97.3}
# 6503 - {'blurriness': 114.6, 'zeros': 1.344}
# 6505 - {'kurtosis': 5.324}
# 6506 - {'blurriness': 90.8}
# 6510 - {'entropy': 4.277, 'contrast': 3.355, 'zeros': 2.938}
# 6520 - {'blurriness': 119.56}
# 6523 - {'kurtosis': 1.94}
# 6538 - {'zeros': 0.8853}
# 6546 - {'kurtosis': 2.303}
# 6549 - {'kurtosis': 7.816, 'entropy': 4.13}
# 6551 - {'blurriness': 97.75}
# 6555 - {'entropy': 4.06, 'contrast': 3.812, 'zeros': 8.04}
# 6558 - {'entropy': 3.352}
# 6559 - {'blurriness': 111.1}
# 6560 - {'blurriness': 100.1}
# 6563 - {'entropy': 4.242}
# 6564 - {'zeros': 0.6978}
# 6567 - {'blurriness': 102.44}
# 6574 - {'kurtosis': 1.88}
# 6585 - {'kurtosis': 2.174}
# 6595 - {'entropy': 3.86}
# 6597 - {'zeros': 0.7603}
# 6599 - {'blurriness': 102.9}
# 6601 - {'blurriness': 95.25}
# 6608 - {'kurtosis': 2.076}
# 6618 - {'entropy': 4.266}
# 6621 - {'kurtosis': 1.774}
# 6625 - {'skew': 2.145, 'kurtosis': 6.84}
# 6636 - {'blurriness': 113.9}
# 6640 - {'entropy': 3.908}
# 6644 - {'kurtosis': 2.26, 'entropy': 4.1}
# 6653 - {'kurtosis': 3.49}
# 6656 - {'zeros': 0.9585}
# 6668 - {'blurriness': 114.9}
# 6669 - {'blurriness': 112.3}
# 6675 - {'var': 0.1501, 'entropy': 3.373}
# 6677 - {'kurtosis': 2.209}
# 6694 - {'contrast': 3.408, 'zeros': 8.09}
# 6696 - {'kurtosis': 2.9}
# 6703 - {'blurriness': 95.2}
# 6708 - {'kurtosis': 1.998}
# 6712 - {'kurtosis': 2.438}
# 6713 - {'kurtosis': 3.486}
# 6720 - {'blurriness': 101.94}
# 6721 - {'zeros': 1.114}
# 6724 - {'zeros': 0.6665}
# 6738 - {'blurriness': 95.75}
# 6740 - {'blurriness': 110.4}
# 6742 - {'entropy': 3.814}
# 6842 - {'kurtosis': 1.83}
# 6860 - {'kurtosis': 1.915}
# 6880 - {'zeros': 1.386}
# 6881 - {'entropy': 4.176, 'zeros': 0.604}
# 6885 - {'skew': 2.229, 'kurtosis': 4.72, 'entropy': 3.326, 'contrast': 4.332, 'zeros': 5.125}
# 6892 - {'zeros': 2.5}
# 6894 - {'kurtosis': 1.756}
# 6902 - {'blurriness': 101.1}
# 6909 - {'blurriness': 92.44}
# 6917 - {'kurtosis': 2.068}
# 6920 - {'blurriness': 110.25}
# 6922 - {'blurriness': 102.3}
# 6927 - {'zeros': 2.531}
# 6930 - {'entropy': 4.19}
# 6937 - {'kurtosis': 1.7}
# 6939 - {'kurtosis': 2.205, 'entropy': 4.164}
# 6941 - {'kurtosis': 1.91, 'entropy': 3.459, 'contrast': 3.334}
# 6942 - {'var': 0.1583}
# 6943 - {'blurriness': 110.9}
# 6949 - {'kurtosis': 2.084}
# 6950 - {'kurtosis': 2.596}
# 6951 - {'kurtosis': 2.254}
# 6970 - {'skew': -3.773, 'kurtosis': 24.42, 'entropy': 3.885, 'darkness': 0.792}
# 6985 - {'kurtosis': 1.674}
# 6997 - {'entropy': 4.285, 'darkness': 0.753}
# 7000 - {'kurtosis': 3.184}
# 7010 - {'entropy': 3.035, 'darkness': 0.7725}
# 7015 - {'blurriness': 109.7}
# 7019 - {'blurriness': 109.0}
# 7022 - {'skew': -3.666, 'kurtosis': 16.4, 'entropy': 3.818, 'darkness': 0.8315}
# 7023 - {'skew': -2.59, 'kurtosis': 7.152, 'entropy': 3.8, 'darkness': 0.7334}
# 7057 - {'blurriness': 98.5}
# 7064 - {'kurtosis': 2.459}
# 7072 - {'kurtosis': 2.498}
# 7074 - {'skew': -2.242, 'kurtosis': 4.72}
# 7081 - {'kurtosis': 2.012}
# 7092 - {'blurriness': 90.7}
# 7100 - {'var': 0.1317}
# 7105 - {'skew': 3.656, 'kurtosis': 14.414, 'entropy': 3.605, 'contrast': 3.434}
# 7107 - {'blurriness': 99.75}
# 7109 - {'kurtosis': 2.104}
# 7112 - {'entropy': 3.666}
# 7116 - {'darkness': 0.7764}
# 7117 - {'var': 0.1292}
# 7131 - {'kurtosis': 2.105}
# 7143 - {'kurtosis': 2.744}
# 7145 - {'contrast': 3.365}
# 7150 - {'kurtosis': 4.562}
# 7164 - {'darkness': 0.787}
# 7172 - {'kurtosis': 2.762}
# 7181 - {'blurriness': 93.3}
# 7190 - {'blurriness': 100.0}
# 7192 - {'entropy': 3.836}
# 7196 - {'entropy': 3.271}
# 7206 - {'entropy': 4.15}
# 7209 - {'skew': -2.22, 'kurtosis': 5.77, 'entropy': 3.84}
# 7210 - {'zeros': 0.6147}
# 7218 - {'blurriness': 91.94}
# 7222 - {'kurtosis': 2.607}
# 7225 - {'entropy': 4.17}
# 7230 - {'blurriness': 104.3}
# 7241 - {'contrast': 3.291, 'zeros': 5.207}
# 7242 - {'kurtosis': 3.129, 'contrast': 3.342}
# 7245 - {'blurriness': 95.06}
# 7255 - {'zeros': 1.458}
# 7256 - {'blurriness': 94.1}
# 7259 - {'blurriness': 91.5}
# 7264 - {'blurriness': 103.06}
# 7266 - {'kurtosis': 3.0}
# 7282 - {'blurriness': 95.3, 'zeros': 0.5522}
# 7289 - {'mean': 0.892, 'skew': -2.148, 'kurtosis': 4.33, 'entropy': 4.13, 'darkness': 0.8706}
# 7294 - {'kurtosis': 2.008}
# 7301 - {'blurriness': 96.1}
# 7316 - {'zeros': 8.78}
# 7318 - {'blurriness': 98.44}
# 7325 - {'blurriness': 114.8}
# 7336 - {'blurriness': 101.9}
# 7338 - {'blurriness': 106.44}
# 7339 - {'blurriness': 112.94}
# 7345 - {'var': 0.1298}
# 7347 - {'skew': -3.783, 'kurtosis': 14.6, 'entropy': 3.416}
# 7356 - {'skew': -1.979, 'kurtosis': 7.027}
# 7359 - {'blurriness': 108.94}
# 7363 - {'zeros': 0.5835}
# 7365 - {'blurriness': 99.2}
# 7383 - {'blurriness': 108.4}
# 7384 - {'var': 0.1514, 'zeros': 2.344}
# 7391 - {'blurriness': 115.6}
# 7401 - {'zeros': 1.698}
# 7410 - {'skew': 2.164, 'kurtosis': 8.4}
# 7420 - {'blurriness': 99.56}
# 7421 - {'zeros': 1.239}
# 7438 - {'zeros': 0.6147}
# 7444 - {'blurriness': 104.75}
# 7449 - {'blurriness': 116.6}
# 7454 - {'blurriness': 105.56}
# 7465 - {'kurtosis': 3.2}
# 7486 - {'blurriness': 107.94, 'zeros': 2.104}
# 7504 - {'zeros': 0.5625}
# 7519 - {'kurtosis': 4.797}
# 7523 - {'entropy': 3.443, 'darkness': 0.855}
# 7529 - {'blurriness': 113.25}
# 7530 - {'kurtosis': 2.566}
# 7537 - {'blurriness': 92.44}
# 7544 - {'entropy': 4.156}
# 7550 - {'zeros': 0.9272}
# 7589 - {'blurriness': 104.3}
# 7591 - {'blurriness': 96.1}
# 7594 - {'entropy': 3.885}
# 7606 - {'blurriness': 102.25}
# 7607 - {'entropy': 4.047}
# 7624 - {'kurtosis': 2.344}
# 7634 - {'zeros': 0.448}
# 7645 - {'kurtosis': 2.459}
# 7650 - {'kurtosis': 5.664}
# 7651 - {'blurriness': 99.4}
# 7655 - {'kurtosis': 3.293, 'entropy': 4.23}
# 7656 - {'entropy': 3.742}
# 7669 - {'kurtosis': 2.232}
# 7681 - {'entropy': 4.062}
# 7691 - {'zeros': 0.4583}
# 7697 - {'entropy': 3.775}
# 7698 - {'kurtosis': 3.035, 'entropy': 4.207}
# 7708 - {'blurriness': 120.2}
# 7709 - {'kurtosis': 3.54}
# 7720 - {'kurtosis': 2.48}
# 7735 - {'skew': -2.04, 'kurtosis': 3.697, 'darkness': 0.784}
# 7736 - {'kurtosis': 1.677}
# 7742 - {'kurtosis': 1.718, 'entropy': 4.22}
# 7746 - {'kurtosis': 1.99}
# 7763 - {'entropy': 3.94}
# 7764 - {'kurtosis': 3.02}
# 7779 - {'blurriness': 95.5}
# 7784 - {'kurtosis': 4.24}
# 7789 - {'zeros': 1.667}
# 7791 - {'kurtosis': 2.754}
# 7794 - {'entropy': 3.316, 'contrast': 3.979, 'zeros': 13.48}
# 7803 - {'mean': 0.929, 'skew': -2.84, 'kurtosis': 6.996, 'entropy': 2.615, 'darkness': 0.9844}
# 7810 - {'kurtosis': 2.143}
# 7811 - {'blurriness': 96.9}
# 7813 - {'mean': 0.8916, 'entropy': 4.02, 'darkness': 0.8276}
# 7821 - {'blurriness': 102.2}
# 7831 - {'blurriness': 101.56}
# 7835 - {'var': 0.1357, 'entropy': 2.18, 'darkness': 0.9414, 'zeros': 0.8438}
# 7840 - {'zeros': 0.7812}
# 7845 - {'zeros': 0.854}
# 7853 - {'skew': 3.504, 'kurtosis': 13.04, 'entropy': 3.86}
# 7857 - {'kurtosis': 2.03}
# 7864 - {'zeros': 0.9897}
# 7870 - {'kurtosis': 1.754, 'contrast': 3.371}
# 7881 - {'blurriness': 105.2}
# 7896 - {'kurtosis': 2.182}
# 7900 - {'zeros': 1.3125}
# 7907 - {'blurriness': 96.44}
# 7916 - {'kurtosis': 1.683, 'entropy': 4.01, 'blurriness': 96.56}
# 7935 - {'kurtosis': 2.316}
# 7940 - {'kurtosis': 3.85}
# 7941 - {'kurtosis': 2.139}
# 7944 - {'entropy': 3.715}
# 7970 - {'entropy': 4.062}
# 7987 - {'kurtosis': 2.766}
# 7994 - {'kurtosis': 3.303, 'entropy': 4.04}
# 8001 - {'kurtosis': 1.97}
# 8002 - {'zeros': 1.7705}
# 8014 - {'blurriness': 94.4}
# 8017 - {'entropy': 4.164, 'blurriness': 99.4}
# 8020 - {'blurriness': 92.5}
# 8030 - {'entropy': 3.855}
# 8055 - {'kurtosis': 3.15}
# 8059 - {'zeros': 0.5312}
# 8061 - {'mean': 0.877, 'skew': -2.727, 'kurtosis': 9.28, 'entropy': 4.2, 'darkness': 0.859}
# 8069 - {'kurtosis': 1.708}
# 8070 - {'entropy': 4.195, 'contrast': 3.469}
# 8074 - {'zeros': 0.6147}
# 8087 - {'blurriness': 96.06}
# 8094 - {'zeros': 1.531}
# 8095 - {'kurtosis': 2.24}
# 8100 - {'blurriness': 102.6}
# 8106 - {'entropy': 4.16}
# 8109 - {'blurriness': 118.6}
# 8121 - {'kurtosis': 3.795}
# 8153 - {'skew': -2.33, 'kurtosis': 6.02}
# 8161 - {'var': 0.1306}
# 8172 - {'kurtosis': 3.336}
# 8180 - {'blurriness': 108.8}
# 8230 - {'entropy': 3.992, 'darkness': 0.8354}
# 8236 - {'entropy': 4.06}
# 8241 - {'kurtosis': 2.207, 'darkness': 0.7725}
# 8244 - {'kurtosis': 3.43, 'entropy': 3.621, 'contrast': 4.17, 'zeros': 5.01}
# 8273 - {'blurriness': 91.3}
# 8290 - {'kurtosis': 5.7}
# 8309 - {'blurriness': 118.9}
# 8313 - {'blurriness': 93.8}
# 8317 - {'kurtosis': 2.436}
# 8318 - {'kurtosis': 2.273, 'contrast': 3.42}
# 8334 - {'kurtosis': 2.453}
# 8338 - {'blurriness': 99.0}
# 8344 - {'zeros': 0.427}
# 8348 - {'kurtosis': 2.799, 'contrast': 3.576}
# 8357 - {'entropy': 3.541}
# 8359 - {'blurriness': 114.56}
# 8366 - {'zeros': 1.083}
# 8370 - {'blurriness': 90.56}
# 8371 - {'zeros': 0.5103}
# 8381 - {'entropy': 3.812, 'contrast': 3.898, 'zeros': 7.426}
# 8383 - {'kurtosis': 3.27}
# 8384 - {'var': 0.1288}
# 8397 - {'kurtosis': 2.715}
# 8419 - {'kurtosis': 1.757}
# 8425 - {'blurriness': 110.44}
# 8435 - {'zeros': 2.385}
# 8448 - {'kurtosis': 2.38, 'entropy': 3.295, 'contrast': 4.41, 'zeros': 3.865}
# 8449 - {'kurtosis': 3.947, 'contrast': 3.664}
# 8462 - {'kurtosis': 2.967}
# 8469 - {'blurriness': 117.7}
# 8476 - {'kurtosis': 5.35}
# 8482 - {'entropy': 2.908}
# 8484 - {'zeros': 1.208}
# 8485 - {'kurtosis': 2.613}
# 8492 - {'zeros': 0.4583}
# 8493 - {'kurtosis': 2.193}
# 8497 - {'blurriness': 97.75}
# 8500 - {'blurriness': 114.75}
# 8504 - {'zeros': 0.4792}
# 8529 - {'zeros': 0.75}
# 8537 - {'var': 0.1428, 'entropy': 4.004}
# 8542 - {'kurtosis': 1.708}
# 8562 - {'blurriness': 106.44}
# 8580 - {'zeros': 0.4688}
# 8595 - {'entropy': 3.982, 'contrast': 3.912, 'zeros': 5.957}
# 8598 - {'zeros': 1.594}
# 8621 - {'entropy': 3.646}
# 8638 - {'skew': -2.621, 'kurtosis': 7.793, 'entropy': 4.164, 'darkness': 0.753}
# 8647 - {'blurriness': 118.44}
# 8648 - {'entropy': 3.49}
# 8654 - {'zeros': 0.4792}
# 8666 - {'entropy': 3.85}
# 8684 - {'var': 0.1536, 'entropy': 3.473, 'zeros': 9.445}
# 8687 - {'entropy': 4.094}
# 8690 - {'kurtosis': 1.99}
# 8694 - {'kurtosis': 1.755, 'entropy': 4.156}
# 8707 - {'entropy': 4.254}
# 8714 - {'kurtosis': 2.107}
# 8716 - {'entropy': 4.15}
# 8720 - {'kurtosis': 2.186, 'entropy': 4.047}
# 8722 - {'entropy': 4.12, 'contrast': 3.541, 'zeros': 9.85}
# 8726 - {'zeros': 0.729}
# 8741 - {'blurriness': 96.7}
# 8742 - {'zeros': 1.375}
# 8743 - {'zeros': 2.99}
# 8753 - {'blurriness': 95.94}
# 8756 - {'blurriness': 105.0}
# 8767 - {'kurtosis': 2.05}
# 8768 - {'skew': 2.908, 'kurtosis': 12.65, 'contrast': 3.623}
# 8771 - {'blurriness': 90.94}
# 8775 - {'zeros': 0.6978}
# 8784 - {'blurriness': 104.2}
# 8800 - {'skew': -2.229, 'kurtosis': 5.22, 'entropy': 3.32, 'darkness': 0.7607}
# 8810 - {'zeros': 4.062}
# 8812 - {'entropy': 3.684, 'darkness': 0.7607}
# 8813 - {'zeros': 0.4583}
# 8815 - {'zeros': 0.6875}
# 8816 - {'blurriness': 103.4}
# 8820 - {'entropy': 3.465}
# 8822 - {'kurtosis': 2.83}
# 8831 - {'zeros': 0.448}
# 8835 - {'entropy': 4.12, 'contrast': 3.73, 'zeros': 4.543}
# 8837 - {'var': 0.1431, 'entropy': 3.934, 'zeros': 0.427}
# 8841 - {'kurtosis': 2.525}
# 8845 - {'blurriness': 111.0}
# 8850 - {'kurtosis': 1.602, 'contrast': 3.438}
# 8851 - {'entropy': 3.854}
# 8856 - {'skew': -3.588, 'kurtosis': 12.75, 'entropy': 2.59}
# 8903 - {'mean': 0.935, 'skew': -2.488, 'kurtosis': 5.68, 'entropy': 2.352, 'darkness': 0.9883}
# 8924 - {'blurriness': 111.56}
# 8925 - {'skew': -2.076, 'kurtosis': 6.51}
# 8928 - {'kurtosis': 4.145}
# 8951 - {'kurtosis': 1.705}
# 8954 - {'blurriness': 111.7}
# 8959 - {'zeros': 0.7085}
# 8960 - {'skew': -4.758, 'kurtosis': 28.03, 'entropy': 3.508, 'darkness': 0.851}
# 8963 - {'blurriness': 91.2}
# 8968 - {'kurtosis': 2.244}
# 8971 - {'kurtosis': 3.963}
# 8974 - {'blurriness': 112.94}
# 8982 - {'contrast': 3.531}
# 8987 - {'skew': 2.105, 'kurtosis': 4.957}
# 8988 - {'entropy': 3.87, 'darkness': 0.753}
# 8991 - {'kurtosis': 1.7}
# 9017 - {'kurtosis': 1.974, 'entropy': 3.885}
# 9021 - {'entropy': 4.22}
# 9031 - {'kurtosis': 3.705}
# 9034 - {'blurriness': 114.75}
# 9044 - {'kurtosis': 1.725}
# 9045 - {'entropy': 3.328}
# 9052 - {'entropy': 2.729, 'darkness': 0.7646}
# 9059 - {'kurtosis': 3.639}
# 9074 - {'blurriness': 99.3}
# 9075 - {'entropy': 3.945}
# 9080 - {'kurtosis': 2.523, 'darkness': 0.741}
# 9090 - {'blurriness': 98.44}
# 9108 - {'blurriness': 118.8}
# 9116 - {'blurriness': 99.4}
# 9119 - {'blurriness': 120.2}
# 9128 - {'skew': 2.111, 'kurtosis': 3.998, 'entropy': 3.787}
# 9154 - {'entropy': 3.613}
# 9163 - {'blurriness': 99.2}
# 9169 - {'entropy': 4.195}
# 9170 - {'zeros': 0.4688}
# 9172 - {'zeros': 1.208}
# 9181 - {'blurriness': 94.94}
# 9193 - {'skew': 2.195, 'kurtosis': 9.77, 'entropy': 3.11}
# 9198 - {'kurtosis': 2.354}
# 9205 - {'blurriness': 98.7}
# 9206 - {'kurtosis': 2.416}
# 9212 - {'zeros': 0.6875}
# 9232 - {'blurriness': 103.3}
# 9234 - {'kurtosis': 3.543}
# 9241 - {'blurriness': 107.0}
# 9246 - {'skew': 3.19, 'kurtosis': 10.14, 'entropy': 2.686, 'brightness': 0.0353, 'contrast': 4.824, 'zeros': 16.05}
# 9250 - {'zeros': 1.125}
# 9255 - {'zeros': 1.458}
# 9269 - {'kurtosis': 2.885}
# 9270 - {'var': 0.1342}
# 9290 - {'blurriness': 115.44}
# 9323 - {'zeros': 2.572}
# 9328 - {'contrast': 3.348, 'zeros': 6.406}
# 9337 - {'kurtosis': 2.531}
# 9344 - {'kurtosis': 2.744, 'contrast': 3.719, 'zeros': 0.6147}
# 9354 - {'kurtosis': 2.264, 'darkness': 0.7646}
# 9356 - {'skew': -2.121, 'kurtosis': 5.41, 'entropy': 3.986}
# 9358 - {'zeros': 0.5312}
# 9365 - {'kurtosis': 1.9375}
# 9385 - {'zeros': 5.73}
# 9403 - {'contrast': 3.418, 'zeros': 7.574}
# 9426 - {'blurriness': 108.4}
# 9430 - {'kurtosis': 2.42}
# 9452 - {'kurtosis': 4.062}
# 9462 - {'kurtosis': 5.96, 'entropy': 3.873}
# 9473 - {'blurriness': 98.5}
# 9482 - {'var': 0.1571, 'entropy': 4.26, 'zeros': 0.5522}
# 9486 - {'kurtosis': 1.884}
# 9491 - {'kurtosis': 3.615}
# 9495 - {'entropy': 3.934, 'blurriness': 116.44}
# 9506 - {'kurtosis': 2.912}
# 9512 - {'kurtosis': 2.23, 'entropy': 4.156}
# 9520 - {'var': 0.1294}
# 9548 - {'entropy': 3.701}
# 9551 - {'kurtosis': 3.762}
# 9556 - {'kurtosis': 1.729}
# 9565 - {'entropy': 3.416}
# 9573 - {'blurriness': 92.4}
# 9590 - {'blurriness': 107.6, 'zeros': 4.2}
# 9592 - {'zeros': 0.5}
# 9597 - {'zeros': 0.5415}
# 9599 - {'var': 0.1388}
# 9601 - {'zeros': 7.387}
# 9608 - {'blurriness': 92.2}
# 9609 - {'kurtosis': 4.676, 'contrast': 3.363}
# 9610 - {'kurtosis': 1.961}
# 9613 - {'blurriness': 108.8}
# 9616 - {'zeros': 0.625}
# 9630 - {'blurriness': 108.8}
# 9633 - {'entropy': 3.277}
# 9636 - {'kurtosis': 1.69}
# 9640 - {'blurriness': 114.25}
# 9665 - {'blurriness': 96.94}
# 9673 - {'kurtosis': 1.747}
# 9681 - {'skew': 2.303, 'kurtosis': 9.62}
# 9685 - {'kurtosis': 2.174}
# 9686 - {'zeros': 0.8228}
# 9689 - {'blurriness': 92.8}
# 9699 - {'zeros': 0.5625}
# 9700 - {'kurtosis': 2.701}
# 9705 - {'kurtosis': 1.711, 'contrast': 3.375, 'zeros': 2.791}
# 9713 - {'zeros': 0.8125}
# 9724 - {'kurtosis': 2.443}
# 9738 - {'kurtosis': 3.11}
# 9744 - {'zeros': 0.9062}
# 9746 - {'entropy': 3.729}
# 9747 - {'skew': -1.896, 'kurtosis': 2.95, 'darkness': 0.7607}
# 9750 - {'blurriness': 101.1}
# 9751 - {'kurtosis': 2.018}
# 9763 - {'zeros': 8.78}
# 9765 - {'kurtosis': 1.694, 'entropy': 3.613, 'contrast': 3.947, 'zeros': 5.76}
# 9766 - {'blurriness': 111.8}
# 9767 - {'blurriness': 96.9}
# 9768 - {'blurriness': 102.25}
# 9776 - {'kurtosis': 11.68, 'entropy': 4.13}
# 9782 - {'kurtosis': 5.57}
# 9783 - {'blurriness': 101.4, 'zeros': 0.5728}
# 9787 - {'blurriness': 91.0}
# 9801 - {'var': 0.1432, 'zeros': 3.49}
# 9802 - {'entropy': 3.793, 'darkness': 0.8745}
# 9805 - {'entropy': 3.889}
# 9822 - {'blurriness': 107.94}
# 9841 - {'skew': -2.164, 'kurtosis': 4.94}
# 9842 - {'kurtosis': 2.725}
# 9848 - {'mean': 0.9287, 'skew': -2.375, 'kurtosis': 4.66, 'entropy': 2.16, 'darkness': 0.9883}
# 9849 - {'blurriness': 109.8}
# 9853 - {'blurriness': 94.7}
# 9857 - {'zeros': 4.625}
# 9858 - {'kurtosis': 2.48}
# 9873 - {'kurtosis': 1.672}
# 9899 - {'var': 0.1367}
# 9902 - {'zeros': 0.9375}
# 9907 - {'kurtosis': 2.143}
# 9912 - {'kurtosis': 2.166}
# 9916 - {'entropy': 3.686}
# 9921 - {'mean': 0.944, 'skew': -3.31, 'kurtosis': 10.8, 'entropy': 2.861, 'darkness': 0.9688}
# 9924 - {'skew': -1.881, 'kurtosis': 4.42}
# 9935 - {'zeros': 0.6665}
# 9936 - {'entropy': 4.215}
# 9951 - {'kurtosis': 1.855, 'darkness': 0.753}
# 9962 - {'blurriness': 100.44}
# 9964 - {'blurriness': 97.4}
# 9966 - {'zeros': 0.8647}
# 9973 - {'entropy': 4.082}
# 9980 - {'zeros': 0.8853}
# 9986 - {'kurtosis': 2.27}
# 9989 - {'blurriness': 106.25}
