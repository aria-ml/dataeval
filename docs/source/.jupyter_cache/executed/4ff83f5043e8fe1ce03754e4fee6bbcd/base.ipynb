# %%
# Google Colab Only
try:
    import google.colab  # noqa: F401

    # specify the version of DataEval (==X.XX.X) for versions other than the latest
    # %pip install -q dataeval maite-datasets
except Exception:
    pass

# %%
from dataclasses import asdict

import numpy as np
from maite_datasets.image_classification import MNIST

from dataeval import Metadata
from dataeval.quality import Duplicates
from dataeval.selection import Indices, Select

# %%
# Load in the mnist dataset
testing_dataset = MNIST(root="./data/", image_set="test", download=True)

# Get the labels
labels = Metadata(testing_dataset).class_labels

# %%
# Creating some indices to duplicate
print("Exact duplicates")
duplicates = {}
for i in [1, 2, 5, 9]:
    matching_indices = np.where(labels == i)[0]
    print(f"\t{i} - ({matching_indices[23]}, {matching_indices[78]})")
    duplicates[int(matching_indices[78])] = int(matching_indices[23])
# Out:
# Exact duplicates
# 	1 - (180, 663)
# 	2 - (249, 728)
# 	5 - (219, 866)
# 	9 - (212, 773)

# %%
# Create a subset with the identified duplicate indices swapped
indices_with_duplicates = [duplicates.get(i, i) for i in range(len(testing_dataset))]
duplicates_ds = Select(testing_dataset, Indices(indices_with_duplicates))

# %%
# Initialize the Duplicates class to begin to identify duplicate images.
identifyDuplicates = Duplicates()

# Evaluate the data
results = identifyDuplicates.evaluate(duplicates_ds)

# %%
for category, dupe_types in results.data().items():
    for dupe_type, groups in asdict(dupe_types).items():
        if groups is not None:
            print(f"{dupe_type} duplicate {category} : {len(groups)}")
            for group in groups:
                print(f"\t{group}")
# Out:
# exact duplicate items : 4
# 	[180, 663]
# 	[212, 773]
# 	[219, 866]
# 	[249, 728]
# near duplicate items : 129
# 	{'indices': (14, 8575), 'methods': frozenset({'dhash'}), 'orientation': None}
# 	{'indices': (39, 2912, 3673, 5534, 5544, 6397, 6809, 6848), 'methods': frozenset({'phash', 'dhash'}), 'orientation': None}
# 	{'indices': (57, 4039), 'methods': frozenset({'phash'}), 'orientation': None}
# 	{'indices': (135, 2786, 2997, 3900, 4035, 4104, 5590, 6159, 8488), 'methods': frozenset({'phash', 'dhash'}), 'orientation': None}
# 	{'indices': (145, 2171), 'methods': frozenset({'dhash'}), 'orientation': None}
# 	{'indices': (154, 180, 196, 203, 239, 272, 279, 314, 330, 419, 430, 652, 663, 783, 918, 920, 948, 984, 1011, 1075, 1083, 1137, 1238, 1254, 1424, 1657, 1728, 1760, 1830, 2034, 2041, 2164, 2379, 2444, 2473, 2541, 2599, 2822, 2827, 2867, 2878, 3003, 3070, 3152, 3430, 3455, 3480, 3546, 3699, 3919, 4014, 4050, 4069, 4085, 4179, 4190, 4191, 4264, 4386, 4524, 4525, 4651, 4871, 4953, 5211, 5524, 5535, 5553, 5637, 5651, 5699, 5880, 5889, 5896, 5917, 6891, 7658, 7686, 7717, 8459, 8658, 9120, 9265, 9282, 9295, 9336, 9368, 9395, 9415, 9443, 9464, 9499), 'methods': frozenset({'phash', 'dhash'}), 'orientation': None}
# 	{'indices': (176, 5872), 'methods': frozenset({'phash'}), 'orientation': None}
# 	{'indices': (178, 1867, 1876, 6141, 6901, 6917, 7280, 8068), 'methods': frozenset({'phash'}), 'orientation': None}
# 	{'indices': (204, 8418), 'methods': frozenset({'phash'}), 'orientation': None}
# 	{'indices': (223, 6171), 'methods': frozenset({'phash'}), 'orientation': None}
# 	{'indices': (255, 3969), 'methods': frozenset({'phash'}), 'orientation': None}
# 	{'indices': (276, 377, 7340), 'methods': frozenset({'phash', 'dhash'}), 'orientation': None}
# 	{'indices': (342, 529), 'methods': frozenset({'dhash'}), 'orientation': None}
# 	{'indices': (348, 1193), 'methods': frozenset({'phash'}), 'orientation': None}
# 	{'indices': (416, 4708, 9324), 'methods': frozenset({'phash', 'dhash'}), 'orientation': None}
# 	{'indices': (476, 1040, 1054, 1643, 5384, 6374, 7270, 9348), 'methods': frozenset({'phash', 'dhash'}), 'orientation': None}
# 	{'indices': (504, 4304, 4676, 6540), 'methods': frozenset({'phash', 'dhash'}), 'orientation': None}
# 	{'indices': (506, 2418, 2655, 4717, 8352), 'methods': frozenset({'phash', 'dhash'}), 'orientation': None}
# 	{'indices': (675, 831, 1434, 4516), 'methods': frozenset({'phash', 'dhash'}), 'orientation': None}
# 	{'indices': (695, 835), 'methods': frozenset({'dhash'}), 'orientation': None}
# 	{'indices': (735, 2688, 3741), 'methods': frozenset({'phash', 'dhash'}), 'orientation': None}
# 	{'indices': (745, 9836), 'methods': frozenset({'phash'}), 'orientation': None}
# 	{'indices': (772, 7636), 'methods': frozenset({'phash'}), 'orientation': None}
# 	{'indices': (809, 6913), 'methods': frozenset({'phash'}), 'orientation': None}
# 	{'indices': (824, 6202), 'methods': frozenset({'dhash'}), 'orientation': None}
# 	{'indices': (836, 9682), 'methods': frozenset({'dhash'}), 'orientation': None}
# 	{'indices': (889, 6073), 'methods': frozenset({'phash'}), 'orientation': None}
# 	{'indices': (929, 1213, 1834, 4273, 4533, 4774, 6125, 6799), 'methods': frozenset({'phash', 'dhash'}), 'orientation': None}
# 	{'indices': (941, 6830), 'methods': frozenset({'phash'}), 'orientation': None}
# 	{'indices': (964, 8672), 'methods': frozenset({'phash'}), 'orientation': None}
# 	{'indices': (967, 1316), 'methods': frozenset({'dhash'}), 'orientation': None}
# 	{'indices': (993, 2937), 'methods': frozenset({'phash'}), 'orientation': None}
# 	{'indices': (1025, 3858, 6634), 'methods': frozenset({'phash', 'dhash'}), 'orientation': None}
# 	{'indices': (1030, 6222), 'methods': frozenset({'dhash'}), 'orientation': None}
# 	{'indices': (1218, 2638), 'methods': frozenset({'dhash'}), 'orientation': None}
# 	{'indices': (1280, 2626), 'methods': frozenset({'phash'}), 'orientation': None}
# 	{'indices': (1338, 3379), 'methods': frozenset({'dhash'}), 'orientation': None}
# 	{'indices': (1448, 1659, 4858, 6115, 6224, 6231), 'methods': frozenset({'phash', 'dhash'}), 'orientation': None}
# 	{'indices': (1484, 2984, 7303), 'methods': frozenset({'phash'}), 'orientation': None}
# 	{'indices': (1515, 1884, 4021, 9081), 'methods': frozenset({'phash', 'dhash'}), 'orientation': None}
# 	{'indices': (1630, 1780, 3652), 'methods': frozenset({'dhash'}), 'orientation': None}
# 	{'indices': (1633, 1836, 1844, 2239, 4006, 6092, 8633, 8666, 9143, 9434), 'methods': frozenset({'phash', 'dhash'}), 'orientation': None}
# 	{'indices': (1674, 3777), 'methods': frozenset({'phash'}), 'orientation': None}
# 	{'indices': (1729, 3452, 6533), 'methods': frozenset({'phash', 'dhash'}), 'orientation': None}
# 	{'indices': (1736, 4331), 'methods': frozenset({'dhash'}), 'orientation': None}
# 	{'indices': (1861, 2674), 'methods': frozenset({'phash'}), 'orientation': None}
# 	{'indices': (1922, 2661, 3253), 'methods': frozenset({'dhash'}), 'orientation': None}
# 	{'indices': (1939, 5614), 'methods': frozenset({'phash'}), 'orientation': None}
# 	{'indices': (2154, 4105), 'methods': frozenset({'dhash'}), 'orientation': None}
# 	{'indices': (2190, 4672), 'methods': frozenset({'dhash'}), 'orientation': None}
# 	{'indices': (2357, 4147), 'methods': frozenset({'phash'}), 'orientation': None}
# 	{'indices': (2434, 4643, 7638), 'methods': frozenset({'phash', 'dhash'}), 'orientation': None}
# 	{'indices': (2442, 7950), 'methods': frozenset({'phash'}), 'orientation': None}
# 	{'indices': (2736, 4936), 'methods': frozenset({'phash'}), 'orientation': None}
# 	{'indices': (2844, 6825), 'methods': frozenset({'dhash'}), 'orientation': None}
# 	{'indices': (2874, 9586), 'methods': frozenset({'phash'}), 'orientation': None}
# 	{'indices': (2950, 9140), 'methods': frozenset({'dhash'}), 'orientation': None}
# 	{'indices': (2974, 5786, 6604), 'methods': frozenset({'dhash'}), 'orientation': None}
# 	{'indices': (3054, 7362), 'methods': frozenset({'phash'}), 'orientation': None}
# 	{'indices': (3196, 7344), 'methods': frozenset({'phash'}), 'orientation': None}
# 	{'indices': (3249, 8757), 'methods': frozenset({'phash'}), 'orientation': None}
# 	{'indices': (3276, 3843, 5873), 'methods': frozenset({'dhash'}), 'orientation': None}
# 	{'indices': (3281, 8090), 'methods': frozenset({'phash'}), 'orientation': None}
# 	{'indices': (3309, 9868), 'methods': frozenset({'dhash'}), 'orientation': None}
# 	{'indices': (3421, 5453), 'methods': frozenset({'phash'}), 'orientation': None}
# 	{'indices': (3590, 5632), 'methods': frozenset({'phash'}), 'orientation': None}
# 	{'indices': (3639, 4977, 5679, 6869, 6902), 'methods': frozenset({'phash', 'dhash'}), 'orientation': None}
# 	{'indices': (3641, 4144, 9335), 'methods': frozenset({'phash', 'dhash'}), 'orientation': None}
# 	{'indices': (3779, 9444), 'methods': frozenset({'dhash'}), 'orientation': None}
# 	{'indices': (3789, 8078, 8493, 9061, 9096), 'methods': frozenset({'dhash'}), 'orientation': None}
# 	{'indices': (3815, 4754, 7019), 'methods': frozenset({'phash', 'dhash'}), 'orientation': None}
# 	{'indices': (3894, 6338), 'methods': frozenset({'phash'}), 'orientation': None}
# 	{'indices': (3895, 3959), 'methods': frozenset({'phash'}), 'orientation': None}
# 	{'indices': (3925, 9241), 'methods': frozenset({'dhash'}), 'orientation': None}
# 	{'indices': (4036, 4153), 'methods': frozenset({'dhash'}), 'orientation': None}
# 	{'indices': (4057, 4603), 'methods': frozenset({'dhash'}), 'orientation': None}
# 	{'indices': (4074, 6408), 'methods': frozenset({'phash'}), 'orientation': None}
# 	{'indices': (4077, 5933), 'methods': frozenset({'dhash'}), 'orientation': None}
# 	{'indices': (4138, 8113), 'methods': frozenset({'phash'}), 'orientation': None}
# 	{'indices': (4169, 7323), 'methods': frozenset({'phash'}), 'orientation': None}
# 	{'indices': (4198, 8899), 'methods': frozenset({'phash'}), 'orientation': None}
# 	{'indices': (4328, 4646, 5566), 'methods': frozenset({'phash', 'dhash'}), 'orientation': None}
# 	{'indices': (4409, 6329), 'methods': frozenset({'dhash'}), 'orientation': None}
# 	{'indices': (4428, 4574, 4869, 6083), 'methods': frozenset({'phash', 'dhash'}), 'orientation': None}
# 	{'indices': (4580, 6308), 'methods': frozenset({'phash'}), 'orientation': None}
# 	{'indices': (4606, 5072), 'methods': frozenset({'phash'}), 'orientation': None}
# 	{'indices': (4624, 9101), 'methods': frozenset({'phash'}), 'orientation': None}
# 	{'indices': (4687, 7183), 'methods': frozenset({'dhash'}), 'orientation': None}
# 	{'indices': (4691, 6233), 'methods': frozenset({'dhash'}), 'orientation': None}
# 	{'indices': (4773, 9990), 'methods': frozenset({'phash'}), 'orientation': None}
# 	{'indices': (4864, 9356), 'methods': frozenset({'dhash'}), 'orientation': None}
# 	{'indices': (4975, 8781), 'methods': frozenset({'phash'}), 'orientation': None}
# 	{'indices': (5042, 8006), 'methods': frozenset({'phash'}), 'orientation': None}
# 	{'indices': (5052, 5477), 'methods': frozenset({'dhash'}), 'orientation': None}
# 	{'indices': (5154, 8911), 'methods': frozenset({'phash'}), 'orientation': None}
# 	{'indices': (5271, 5762, 6928, 7353), 'methods': frozenset({'phash', 'dhash'}), 'orientation': None}
# 	{'indices': (5323, 7399, 8252), 'methods': frozenset({'phash'}), 'orientation': None}
# 	{'indices': (5399, 6484, 6976), 'methods': frozenset({'phash'}), 'orientation': None}
# 	{'indices': (5442, 8768), 'methods': frozenset({'dhash'}), 'orientation': None}
# 	{'indices': (5460, 7708, 8005), 'methods': frozenset({'dhash'}), 'orientation': None}
# 	{'indices': (5466, 8401), 'methods': frozenset({'phash'}), 'orientation': None}
# 	{'indices': (5616, 8903), 'methods': frozenset({'phash'}), 'orientation': None}
# 	{'indices': (5722, 6135), 'methods': frozenset({'dhash'}), 'orientation': None}
# 	{'indices': (5848, 6232), 'methods': frozenset({'phash'}), 'orientation': None}
# 	{'indices': (5903, 7300), 'methods': frozenset({'phash'}), 'orientation': None}
# 	{'indices': (6191, 9611), 'methods': frozenset({'dhash'}), 'orientation': None}
# 	{'indices': (6216, 6277), 'methods': frozenset({'dhash'}), 'orientation': None}
# 	{'indices': (6306, 7375, 7390), 'methods': frozenset({'phash'}), 'orientation': None}
# 	{'indices': (6670, 7582, 9878), 'methods': frozenset({'phash'}), 'orientation': None}
# 	{'indices': (6868, 8600), 'methods': frozenset({'dhash'}), 'orientation': None}
# 	{'indices': (7059, 8364), 'methods': frozenset({'phash'}), 'orientation': None}
# 	{'indices': (7149, 7756), 'methods': frozenset({'phash'}), 'orientation': None}
# 	{'indices': (7226, 7567, 8809), 'methods': frozenset({'phash', 'dhash'}), 'orientation': None}
# 	{'indices': (7255, 9951), 'methods': frozenset({'phash'}), 'orientation': None}
# 	{'indices': (7319, 7665), 'methods': frozenset({'dhash'}), 'orientation': None}
# 	{'indices': (7422, 9774), 'methods': frozenset({'dhash'}), 'orientation': None}
# 	{'indices': (7626, 9301), 'methods': frozenset({'phash'}), 'orientation': None}
# 	{'indices': (7784, 8905), 'methods': frozenset({'phash'}), 'orientation': None}
# 	{'indices': (7802, 7954), 'methods': frozenset({'dhash'}), 'orientation': None}
# 	{'indices': (8172, 8978), 'methods': frozenset({'dhash'}), 'orientation': None}
# 	{'indices': (8390, 9802), 'methods': frozenset({'phash'}), 'orientation': None}
# 	{'indices': (8636, 8659), 'methods': frozenset({'dhash'}), 'orientation': None}
# 	{'indices': (8758, 9705), 'methods': frozenset({'phash'}), 'orientation': None}
# 	{'indices': (8850, 9570), 'methods': frozenset({'phash'}), 'orientation': None}
# 	{'indices': (8938, 9969), 'methods': frozenset({'dhash'}), 'orientation': None}
# 	{'indices': (8979, 9222), 'methods': frozenset({'dhash'}), 'orientation': None}
# 	{'indices': (8986, 9725), 'methods': frozenset({'dhash'}), 'orientation': None}
# 	{'indices': (9689, 9819), 'methods': frozenset({'dhash'}), 'orientation': None}
# 	{'indices': (9772, 9796), 'methods': frozenset({'phash'}), 'orientation': None}

# %%
### TEST ASSERTION CELL ###
assert results.items.exact is not None
assert len(results.items.exact) == len(duplicates)
for k, v in duplicates.items():
    assert [v, k] in results.items.exact
